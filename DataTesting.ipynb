# %%
from data_processing import import_and_clean_train, one_hot_encoding, label_encoding, cleaned_dataframe


df, label_lib = cleaned_dataframe('train', label_encoding)


print(df['GrLivArea'])
# Out:
# 0       1710
# 1       1262
# 2       1786
# 3       1717
# 4       2198
#         ...
# 1455    1647
# 1456    2073
# 1457    2340
# 1458    1078
# 1459    1256
# Name: GrLivArea, Length: 1450, dtype: int64

# %%
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns


# Getting top 10 correlated features except saleprice
labels = list(df.corr()['SalePrice'].sort_values(ascending=False).index[1:21])

print(labels)
# Out:
# ['OverallQual', 'GrLivArea', 'TotalBsmtSF', 'GarageCars', 'GarageArea', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'Fireplaces', 'BsmtFinSF1', 'Foundation', 'LotFrontage', 'LotArea', 'WoodDeckSF', '2ndFlrSF', 'OpenPorchSF', 'HalfBath']

# %%
for label in labels: 
    sns.scatterplot(x=label, y='SalePrice', data=df)
    plt.show()
